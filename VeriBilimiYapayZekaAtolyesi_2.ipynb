# %%
# Odev 2- Alistirma 1
#Kullanıcıdan maaş bilgisini istenir ve bu bilgiye göre maaşından ne kadar vergi kesileceğini hesaplanır. 
#Kullanıcının geliri;
#10000 ve altındaysa maaşından %5 kesinti olur.
#25000 ve altındaysa maaşından %10 kesinti olur.
#45000 ve altındaysa maaşından %25 kesinti olur.
#Diğer koşullarda %30 kesinti olur.
#Bu durumlara göre kullanıcının yeni maaşı yazdırılır.

maas_str = input("Lütfen maaşınızı giriniz:")
maas = float (maas_str)

if maas <= 10000:
    kesinti = maas*0.05
    print("Vergi kesintisi %5'tir. Yeni Maaşınız=", kesinti)

elif maas <= 25000:
     kesinti = maas*0.10
     print("Vergi kesintisi %10'dur. Yeni Maaşınız=", kesinti)

elif maas <= 45000:
     kesinti = maas*0.25     
     print("Vergi kesintisi %25'dir. Yeni Maaşınız=", kesinti)

else:
     kesinti = maas*0.30
     print("Vergi kesintisi %30'dur. Yeni Maaşınız=", kesinti)
# Out:
# Lütfen maaşınızı giriniz: 25000
# Vergi kesintisi %10'dur. Yeni Maaşınız= 2500.0

# %%
# Odev 2- Alistirma 2 
# Kullanıcıdan kullanıcı adı ve şifre oluşturmasını istenir. 
# Şifrenin uzunluğu altı haneye ulaşmışsa hesabınız oluşturuldu mesajı alınır.
# Altı haneden azsa altı haneli şifre oluşturması gerektiğinin mesajı alınır. 

Kullanici_Adi = input ("Kullanıcı adı oluşturun:")
Sifre = input("En az altı haneli bir şifre oluşturun:")

Sifre1 = len(Sifre)

if Sifre1 >= 6:
    print("Hesabınız başarı ile oluşturuldu.")

else:
    print("Şifreniz en az 6 haneli olmalıdır.")
# Out:
# Kullanıcı adı oluşturun: bng
# En az altı haneli bir şifre oluşturun: 12345
# Şifreniz en az 6 haneli olmalıdır.

# %%
# Odev 2- Alistirma 3
#Kullanıcı girdiği şifre 5 ve 10 hane arasında olmak zorunda.

sifre = input("En az 5, en fazla 10 haneli bir şifre giriniz.")

sifre1 = len(sifre)

if sifre1 >= 5 and sifre1 <= 10:
    print("Hesabınız başarı ile oluşturuldu.")

else:
    print("Lütfen şifreniz 5 haneden az, 10 haneden fazla olmasın.")
# Out:
# En az 5, en fazla 10 haneli bir şifre giriniz. 11
# Lütfen şifreniz 5 haneden az, 10 haneden fazla olmasın.

# %%
# Odev 2- Alistirma 4
# Kullanıcıdan isim ve şifre isteyeceğiz ve şifre girişi için üç hak verilir.
# Eğer önceden tanımlı şifre ile kullanıcıdan gelen şifre aynıysa "Giriş yapıldı." yazar.
# Şifre girişi yanlışsa "Yanlış şifre girildi!" uyarısı verilsin ve üç yanlış denemede program biter.

tanimli_kullanici = "bngozs"
tanimli_sifre = "123456"
kalan_hak = 3

while kalan_hak > 0:

  kullanici_adi = input("Kullanıcı Adınızı Giriniz =")
  sifre = input ("Şifrenizi Giriniz =")
  if kullanici_adi == tanimli_kullanici and sifre == tanimli_sifre:
      print("Giriş yapıldı. Hoş geldiniz!")break
     else:
         kalan_hak = kalan_hak - 1
         print("Yanlış kullanıcı adı ya da şifre girdiniz. Lütfen tekrar deneyin.")
         if kalan_hak == 0:
             print("3 deneme hakkınız bitti.")
         else:
             print(f"Kalan hakkınız=", {kalan_hak})
# Out:
#   Cell In[19], line 15
#     if kullanici_adi == tanimli_kullanici and sifre == tanimli_sifre:
#     ^
# IndentationError: unexpected indent
